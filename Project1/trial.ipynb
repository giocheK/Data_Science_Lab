# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("./archive/corporate_ai_adoption_dataset.csv")

# %%
df.head()
# Out:
#    company_id            industry        country  year  ai_adoption_level  \
# 0  CORP-06613  Financial Services          China  2029             0.4987
# 1  CORP-01597         Agriculture        Germany  2032             0.5213
# 2  CORP-02938              Energy  United States  2024             0.6147
# 3  CORP-05207              Retail        Germany  2021             0.4401
# 4  CORP-07489          Technology  United States  2024             0.1918
#
#    ai_investment_usd  automation_rate  cost_savings  revenue_impact  \
# 0           11747237           0.4119       3519354         2751513
# 1            1267219           0.4580        295244          304776
# 2            8168951           0.5821       2472329         5170304
# 3            1234261           0.2880        512061         -233448
# 4            5000645           0.1906       2122064         2110644
#
#    productivity_gain  employee_ai_training_hours  ai_maturity_score  \
# ...

# %%
df.isnull().sum()
# Out:
# company_id                    0
# industry                      0
# country                       0
# year                          0
# ai_adoption_level             0
# ai_investment_usd             0
# automation_rate               0
# cost_savings                  0
# revenue_impact                0
# productivity_gain             0
# employee_ai_training_hours    0
# ai_maturity_score             0
# deployment_count              0
# dtype: int64

# %%
df.shape
# Out:
# (200000, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   company_id                  200000 non-null  str
#  1   industry                    200000 non-null  str
#  2   country                     200000 non-null  str
#  3   year                        200000 non-null  int64
#  4   ai_adoption_level           200000 non-null  float64
#  5   ai_investment_usd           200000 non-null  int64
#  6   automation_rate             200000 non-null  float64
#  7   cost_savings                200000 non-null  int64
#  8   revenue_impact              200000 non-null  int64
#  9   productivity_gain           200000 non-null  float64
#  10  employee_ai_training_hours  200000 non-null  float64
#  11  ai_maturity_score           200000 non-null  float64
#  12  deployment_count            200000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['company_id', 'industry', 'country', 'year', 'ai_adoption_level',
#        'ai_investment_usd', 'automation_rate', 'cost_savings',
#        'revenue_impact', 'productivity_gain', 'employee_ai_training_hours',
#        'ai_maturity_score', 'deployment_count'],
#       dtype='str')

# %%
df.describe()
# Out:
#                 year  ai_adoption_level  ai_investment_usd  automation_rate  \
# count  200000.000000      200000.000000       2.000000e+05    200000.000000
# mean     2024.991490           0.527774       4.870558e+06         0.436723
# std         6.051632           0.256470       3.679704e+06         0.217031
# min      2015.000000           0.010000       4.788800e+04         0.000000
# 25%      2020.000000           0.334400       2.221252e+06         0.273500
# 50%      2025.000000           0.528600       3.991640e+06         0.428150
# 75%      2030.000000           0.725000       6.517931e+06         0.592000
# max      2035.000000           1.000000       5.417034e+07         0.950000
#
#        cost_savings  revenue_impact  productivity_gain  \
# count  2.000000e+05    2.000000e+05      200000.000000
# mean   2.128918e+06    2.591989e+06           0.395297
# std    2.415689e+06    3.972751e+06           0.195623
# min    4.649000e+03   -1.437676e+07          -0.050000
# ...

# %%
df.columns
# Out:
# Index(['company_id', 'industry', 'country', 'year', 'ai_adoption_level',
#        'ai_investment_usd', 'automation_rate', 'cost_savings',
#        'revenue_impact', 'productivity_gain', 'employee_ai_training_hours',
#        'ai_maturity_score', 'deployment_count'],
#       dtype='str')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         company_id            industry         country  year  \
# 0       CORP-06613  Financial Services           China  2029
# 1       CORP-01597         Agriculture         Germany  2032
# 2       CORP-02938              Energy   United States  2024
# 3       CORP-05207              Retail         Germany  2021
# 4       CORP-07489          Technology   United States  2024
# ...            ...                 ...             ...   ...
# 199995  CORP-06451              Retail          France  2024
# 199996  CORP-02714              Retail           China  2028
# 199997  CORP-05490          Technology  United Kingdom  2033
# 199998  CORP-07057              Retail     South Korea  2026
# 199999  CORP-00512       Manufacturing         Germany  2017
#
#         ai_adoption_level  ai_investment_usd  automation_rate  cost_savings  \
# 0                  0.4987           11747237           0.4119       3519354
# ...

# %%
df.describe()
# Out:
#                 year  ai_adoption_level  ai_investment_usd  automation_rate  \
# count  200000.000000      200000.000000       2.000000e+05    200000.000000
# mean     2024.991490           0.527774       4.870558e+06         0.436723
# std         6.051632           0.256470       3.679704e+06         0.217031
# min      2015.000000           0.010000       4.788800e+04         0.000000
# 25%      2020.000000           0.334400       2.221252e+06         0.273500
# 50%      2025.000000           0.528600       3.991640e+06         0.428150
# 75%      2030.000000           0.725000       6.517931e+06         0.592000
# max      2035.000000           1.000000       5.417034e+07         0.950000
#
#        cost_savings  revenue_impact  productivity_gain  \
# count  2.000000e+05    2.000000e+05      200000.000000
# mean   2.128918e+06    2.591989e+06           0.395297
# std    2.415689e+06    3.972751e+06           0.195623
# min    4.649000e+03   -1.437676e+07          -0.050000
# ...
